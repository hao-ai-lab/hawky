# %% [markdown]
# # Test Notebook
#
# This is a test notebook for read_file.

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
1 + 2
# Out:
# 3

# %%
raise ValueError('test error')
# Out:
# ValueError: test error
